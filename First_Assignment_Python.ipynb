# %% [markdown]
# # Assignment

# %% [markdown]
# ## Python

# %% [raw]
# 1. Explain the key feature of python that make it a popular choice for programming.
# Sol:
# Following are the key features of python that make it a popular choice for programming:
# i.It is widely used in the industry.
# ii. Used in data industry.
# iii. Python contain Huge number of libraries, it's around 137000.
# iv. It is very easy to learn language.
# v. Readability and Simplicity.
# vi. Interpreted Language.
# vii. Dynamic Typing.
# viii. Versatility.
# ix. Huge active community.

# %% [raw]
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
# Sol:
#     Predefined keywords are the words that hold the special meaning and have specific purpose in python programming.

# %%
#example of how key words use in python
#Example 1
a=int(input("Enter Number here: "))
if(a>0):
    print("Number is +ve")
elif(a==0):
    print("Number is zero")
else:
    print("Number is -ve")
    
#Example 2
count=0
while(count<5):
    print(count)
    count+=1

# %% [raw]
# 3. Compare and contrast mutable and immutable objects in Python with examples.
# Sol:
#
# Mutable Objects:
#     >> Objects/container whose state or value can be changed after they created are called as mutable objects or container.
#     >> List is type of mutable objects or which supports item assignment.
#     >> Examples: Sets, User-defined Classes
#
# Immutable Objects:
#     >> Objects/container whose state or value can not be changed after they created are called as immutable objects or container.
#     >> Examples: Strings, Integers, Floats, Tuples, etc.

# %%
#Mutable Examples

List_count=[1,2,"Nakul","Data Science Course",4.3, 3+5j]
List_count[2]   #'Nakul'
List_count[-4]="Ajay"
List_count[2]   #'Ajay'
print(List_count)  #updated list

#Immutable Examples

a="Nakul"
a[0]   #print N
#a[0]="n" # throw "not support item assignment"
#It means string is immutable

# %% [raw]
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
# Sol:
# Following are the different types of operators in Python:
# i.Arithmetic Operator
# x=5
# y=3
# print(x+y)
# print(x-y)
# print(x*y)
# print(x/y)
#
# ii.floor Operator
# x=3
# x=6
# print(x // y)
#
# iii.Comparison Operator
# x=3
# x=6
# print(x==y)
# print(x!=y)
# print(x>y)
# print(x<y)
# print(x>=y)
# print(x<=y)
#
# iv. Logical Operator
# and
# or
# x=3
# y=6
# print(x>2 and y<5)
# print(x>2 or y<5)
#
# v. Assignment Operator
# x=3
# x+=4
# x-=6
#
# vi. Membership Operator
# a="Nakul"
# "a" in a
# #true
#
# vii. Identity Operator
# a=2
# b=5
# a is b
# #false
#
# viii. Bitwise Operator
# a=4
# b=6
# print(a & b)
# print(a | b)
#
# ix. negation Operator
# ~3
# output=-4
# ~100
# output=-101
#
# x. Shift Operator
# #left shift
# 35<<3
# 280
# #right shift
# 280>>3
# 35

# %% [raw]
# 5. Explain the concept of type casting in python with examples
# Sol:
# Type casting:
#     converting one datatype into another datatype.
# There are two types of Type Casting:
# i. Implicit Type Casting
# ii. Explicit Type Casting
#
#     In implicit type casting, python understand the datatype
#     example,
#     a=10
#     type(a)
#     o/p:int
#
#     In explicit type casting, here python do not understand what actual type of data present there so we need to convert it actual datatype.
#     example,
#     a="2"
#     type(a)
#     o/p:str
#     int(a)
#     o/p:2

# %% [raw]
# 6. How do conditional statements work in python? illustrate with examples.
# Sol:
# Conditional Statements in Python:
# 1.if
# 2.if-else
# 3.if-elif-else
# 4.nested if-else
#
# 1.if: it evalutes condition and executes a block of code if codition is tue.
# ex,
# a=10
# if(a>0):
#     print("Number is positive");
#
# 2.if-else: it provide an alternative block of code to execute is the condition is false.
# ex,
# a=10
# if(a>0):
#     print("Number is positive")
# else:
#     print("Number is negative")
#
# 3.if-elif-else: it uses when you have multiple conditions to evaluate.
# ex,
# if(a>0):
#     print("Number is +ve")
# elif(a=0):
#     print("Number is 0")
# else:
#     print("Number is -ve")

# %% [raw]
# 7. Describe the different types of loops in python and their use cases with examples.
# Sol:
# Loop Statements in python:
# 1.for
# 2.while
#
# 1.for loop: it execute a block of code for each item in the sequence.
# Syntax:
# for variable in sequence:
#
# example:
# a=["Nakul", "Ajay", "Ram"]
# for i in a:
#     print(i)
#
# 2.while loop: repeatedly executes a block of code as long as a specified condition is true.
# Syntax:
# while condition:
#
# example:
# i=0
# while i<5:
#     print(i)
#     i+=1
